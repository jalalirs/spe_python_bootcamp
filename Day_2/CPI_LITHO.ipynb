# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# checking files in dataset
! ls data/
# Out:
# 15_9-19_A_CPI_LITHO.csv     DATA_Harvard_2012_10_31.csv
# 15_9-19_BT2_CPI_LITHO.csv   Merged_Data.csv

# %%
#import the .csv file as a dataframe
data = pd.read_csv('data/15_9-19_A_CPI_LITHO.csv')

# %% [markdown]
# This is a dataset with the following petrophysical information available for analysis
# * Well Count: 1
# * Well Name: 15/9-19 A
# * BVW (V/V) - Bulk Volume Water
# * CARB_FLAG (UNITLESS)
# * COAL_FLAG (UNITLESS)
# * KLOGH (mD) log-evaluated permeability
# * PHIF (V/V) - Fracture Porosity
# * RHOFL (G/CM3) - Bulk Density Fluid
# * RHOMA (G/CM3) - Bulk Density Matrix
# * RW (OHMM) - Water Resistivity
# * SAND_FLAG (UNITLESS)
# * SW (V/V) - Water Saturation
# * TEMP (DEGC) - Temperature in degree C
# * VSH (V/V) - Shale Volume
# * LITHOTYPE - Rock Characteristics

# %%
# show snippet (few rows from top, few rows from bottom)
data
# Out:
#      COMMON_WELL_NAME  DEPTH (M)  BVW (V/V)  CARB_FLAG (UNITLESS)  \
# 0           15/9-19 A  3666.5916   0.111705                   0.0
# 1           15/9-19 A  3666.7440   0.112236                   0.0
# 2           15/9-19 A  3666.8964   0.114825                   0.0
# 3           15/9-19 A  3667.0488   0.114419                   0.0
# 4           15/9-19 A  3667.2012   0.115867                   0.0
# ...               ...        ...        ...                   ...
# 3003        15/9-19 A  4124.2488        NaN                   0.0
# 3004        15/9-19 A  4124.4012        NaN                   0.0
# 3005        15/9-19 A  4124.5536        NaN                   0.0
# 3006        15/9-19 A  4124.7060        NaN                   0.0
# 3007        15/9-19 A  4124.8584        NaN                   0.0
#
#       COAL_FLAG (UNITLESS)  KLOGH (MD)  PHIF (V/V)  RHOFL (G/CM3)  \
# 0                      0.0      0.0003    0.199843            0.8
# ...

# %%
# show top n rows
data.head(20)
# Out:
#    COMMON_WELL_NAME  DEPTH (M)  BVW (V/V)  CARB_FLAG (UNITLESS)  \
# 0         15/9-19 A  3666.5916   0.111705                   0.0
# 1         15/9-19 A  3666.7440   0.112236                   0.0
# 2         15/9-19 A  3666.8964   0.114825                   0.0
# 3         15/9-19 A  3667.0488   0.114419                   0.0
# 4         15/9-19 A  3667.2012   0.115867                   0.0
# 5         15/9-19 A  3667.3536   0.112858                   0.0
# 6         15/9-19 A  3667.5060   0.118716                   0.0
# 7         15/9-19 A  3667.6584   0.124121                   0.0
# 8         15/9-19 A  3667.8108   0.128317                   0.0
# 9         15/9-19 A  3667.9632   0.128881                   0.0
# 10        15/9-19 A  3668.1156   0.127310                   0.0
# 11        15/9-19 A  3668.2680   0.118762                   0.0
# 12        15/9-19 A  3668.4204   0.117522                   0.0
# 13        15/9-19 A  3668.5728   0.118934                   0.0
# ...

# %%
# show trailing n rows
data.tail(20)
# Out:
#      COMMON_WELL_NAME  DEPTH (M)  BVW (V/V)  CARB_FLAG (UNITLESS)  \
# 2988        15/9-19 A  4121.9628        NaN                   NaN
# 2989        15/9-19 A  4122.1152        NaN                   NaN
# 2990        15/9-19 A  4122.2676        NaN                   0.0
# 2991        15/9-19 A  4122.4200        NaN                   0.0
# 2992        15/9-19 A  4122.5724        NaN                   0.0
# 2993        15/9-19 A  4122.7248        NaN                   0.0
# 2994        15/9-19 A  4122.8772        NaN                   0.0
# 2995        15/9-19 A  4123.0296        NaN                   NaN
# 2996        15/9-19 A  4123.1820        NaN                   NaN
# 2997        15/9-19 A  4123.3344        NaN                   0.0
# 2998        15/9-19 A  4123.4868        NaN                   0.0
# 2999        15/9-19 A  4123.6392        NaN                   0.0
# 3000        15/9-19 A  4123.7916        NaN                   0.0
# ...

# %%
# show data index
data.index
# Out:
# RangeIndex(start=0, stop=3008, step=1)

# %%
# show data columns
data.columns
# Out:
# Index(['COMMON_WELL_NAME', 'DEPTH (M)', 'BVW (V/V)', 'CARB_FLAG (UNITLESS)',
#        'COAL_FLAG (UNITLESS)', 'KLOGH (MD)', 'PHIF (V/V)', 'RHOFL (G/CM3)',
#        'RHOMA (G/CM3)', 'RW (OHMM)', 'SAND_FLAG (UNITLESS)', 'SW (V/V)',
#        'TEMP (DEGC)', 'VSH (V/V)', 'LITHOTYPE'],
#       dtype='object')

# %%
# better viz
for c in data.columns:
    print(c)
# Out:
# COMMON_WELL_NAME
# DEPTH (M)
# BVW (V/V)
# CARB_FLAG (UNITLESS)
# COAL_FLAG (UNITLESS)
# KLOGH (MD)
# PHIF (V/V)
# RHOFL (G/CM3)
# RHOMA (G/CM3)
# RW (OHMM)
# SAND_FLAG (UNITLESS)
# SW (V/V)
# TEMP (DEGC)
# VSH (V/V)
# LITHOTYPE

# %%
# dataframe method: info # provides all relevant details like datatype, number of records, range of index
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3008 entries, 0 to 3007
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   COMMON_WELL_NAME      3008 non-null   object
#  1   DEPTH (M)             3008 non-null   float64
#  2   BVW (V/V)             1965 non-null   float64
#  3   CARB_FLAG (UNITLESS)  2692 non-null   float64
#  4   COAL_FLAG (UNITLESS)  3008 non-null   float64
#  5   KLOGH (MD)            1967 non-null   float64
#  6   PHIF (V/V)            1967 non-null   float64
#  7   RHOFL (G/CM3)         3008 non-null   float64
#  8   RHOMA (G/CM3)         1967 non-null   float64
#  9   RW (OHMM)             1965 non-null   float64
#  10  SAND_FLAG (UNITLESS)  1967 non-null   float64
#  11  SW (V/V)              1965 non-null   float64
#  12  TEMP (DEGC)           1965 non-null   float64
#  13  VSH (V/V)             3008 non-null   float64
# ...

# %%
# show inferred column types
data.dtypes
# Out:
# COMMON_WELL_NAME         object
# DEPTH (M)               float64
# BVW (V/V)               float64
# CARB_FLAG (UNITLESS)    float64
# COAL_FLAG (UNITLESS)    float64
# KLOGH (MD)              float64
# PHIF (V/V)              float64
# RHOFL (G/CM3)           float64
# RHOMA (G/CM3)           float64
# RW (OHMM)               float64
# SAND_FLAG (UNITLESS)    float64
# SW (V/V)                float64
# TEMP (DEGC)             float64
# VSH (V/V)               float64
# LITHOTYPE                object
# dtype: object

# %%
# dataframe method: describe, will show summary statistics for each column provided
data.describe()
# Out:
#          DEPTH (M)    BVW (V/V)  CARB_FLAG (UNITLESS)  COAL_FLAG (UNITLESS)  \
# count  3008.000000  1965.000000           2692.000000                3008.0
# mean   3895.725000     0.071881              0.028379                   0.0
# std     132.356219     0.035170              0.165817                   0.0
# min    3666.591600     0.000000              0.000000                   0.0
# 25%    3781.158300     0.044633              0.000000                   0.0
# 50%    3895.725000     0.073641              0.000000                   0.0
# 75%    4010.291700     0.092751              0.000000                   0.0
# max    4124.858400     0.216184              1.000000                   0.0
#
#        KLOGH (MD)   PHIF (V/V)  RHOFL (G/CM3)  RHOMA (G/CM3)    RW (OHMM)  \
# count  1967.00000  1967.000000    3008.000000    1967.000000  1965.000000
# mean    247.95830     0.142429       0.834608       2.656355     0.021097
# ...

# %% [markdown]
# *Important to understand 1D (Series) and 2D (Dataframe) operations*
#
# Series - A array where an index is assigned to a value
#
# Dataframe - A 2D array where an index is assigned to mulitple values and can include multiple columns

# %%
# basic series attributes and methods
rhofl = data['RHOFL (G/CM3)'] # series 1 Bulk Density Fluid
rhoma = data['RHOMA (G/CM3)'] # series 2 Bulk Density Matrix
phif  = data['PHIF (V/V)']    # series 3 Fracture Porosity
# creating a new series 
rhob = rhoma*(1-phif) + (rhofl*phif)
rhob
# Out:
# 0       2.288292
# 1       2.253138
# 2       2.209173
# 3       2.238881
# 4       2.257926
#           ...
# 3003         NaN
# 3004         NaN
# 3005         NaN
# 3006         NaN
# 3007         NaN
# Length: 3008, dtype: float64

# %%
# series attributes: index
rhob.index
# Out:
# RangeIndex(start=0, stop=3008, step=1)

# %%
# series attributes: values
rhob.values
# Out:
# array([2.28829202, 2.25313802, 2.2091732 , ...,        nan,        nan,
#               nan])

# %%
# series attributes: shape
rhob.shape
# Out:
# (3008,)

# %%
# series method: head (same as above)
rhob.head(10)
# Out:
# 0    2.288292
# 1    2.253138
# 2    2.209173
# 3    2.238881
# 4    2.257926
# 5    2.328721
# 6    2.293141
# 7    2.254154
# 8    2.207185
# 9    2.177118
# dtype: float64

# %%
# series method: describe, will show summary statistics
rhob.describe()
# Out:
# count    1967.000000
# mean        2.392224
# std         0.128113
# min         1.991058
# 25%         2.272158
# 50%         2.412099
# 75%         2.485919
# max         2.710000
# dtype: float64

# %%
# renaming column, if inplace = False, you need to reassign the result
# in case wants to reshow: uncomment this
data = pd.read_csv('data/15_9-19_A_CPI_LITHO.csv')
for c in data.columns:
    print(c)
data.rename(columns={'COMMON_WELL_NAME': 'WELL NAME'}, inplace=True)
print()
for c in data.columns:
    print(c)
# Out:
# COMMON_WELL_NAME
# DEPTH (M)
# BVW (V/V)
# CARB_FLAG (UNITLESS)
# COAL_FLAG (UNITLESS)
# KLOGH (MD)
# PHIF (V/V)
# RHOFL (G/CM3)
# RHOMA (G/CM3)
# RW (OHMM)
# SAND_FLAG (UNITLESS)
# SW (V/V)
# TEMP (DEGC)
# VSH (V/V)
# LITHOTYPE
#
# WELL NAME
# DEPTH (M)
# BVW (V/V)
# CARB_FLAG (UNITLESS)
# COAL_FLAG (UNITLESS)
# KLOGH (MD)
# PHIF (V/V)
# RHOFL (G/CM3)
# RHOMA (G/CM3)
# RW (OHMM)
# SAND_FLAG (UNITLESS)
# SW (V/V)
# TEMP (DEGC)
# VSH (V/V)
# LITHOTYPE

# %%
# if memory is not an issue, better not reassign and keep original
# data = pd.read_csv('data/15_9-19_A_CPI_LITHO.csv')
# cleandata = data.rename(columns={'COMMON_WELL_NAME': 'WELL NAME'})

# %%
# adding a column to the dataframe with a constant value
data['Temporary'] = 0.5

# %%
# dropping the temporary column
data.drop(['Temporary'], axis=1, inplace=True)

# %%
# sorting based on a specific column
data.sort_values(['VSH (V/V)', 'PHIF (V/V)'], ascending=[True,False])
# Out:
#       WELL NAME  DEPTH (M)  BVW (V/V)  CARB_FLAG (UNITLESS)  \
# 2252  15/9-19 A  4009.7964        NaN                   0.0
# 1356  15/9-19 A  3873.2460   0.023099                   0.0
# 1708  15/9-19 A  3926.8908   0.066494                   0.0
# 2183  15/9-19 A  3999.2808        NaN                   0.0
# 1692  15/9-19 A  3924.4524   0.049259                   0.0
# ...         ...        ...        ...                   ...
# 381   15/9-19 A  3724.6560   0.092378                   0.0
# 284   15/9-19 A  3709.8732   0.071403                   0.0
# 283   15/9-19 A  3709.7208   0.065020                   0.0
# 294   15/9-19 A  3711.3972   0.080068                   0.0
# 282   15/9-19 A  3709.5684   0.064654                   0.0
#
#       COAL_FLAG (UNITLESS)  KLOGH (MD)  PHIF (V/V)  RHOFL (G/CM3)  \
# 2252                   0.0         NaN         NaN            0.9
# 1356                   0.0   3177.2886    0.210934            0.8
# ...

# %%
# creating a filter with only values more than 0 for PHIF (V/V)
filter_por = data['PHIF (V/V)'] > 0

# %%
data_filtered = data[filter_por]
print("shape before:",data.shape)
print("shape after:",data_filtered.shape)
# Out:
# shape before: (3008, 15)
# shape after: (1925, 15)

# %%
# dropping NA from the dataframe 
print("shape before:",data.shape)
data.dropna(how='any', axis = 0, inplace=True) # axis = 1 denotes columns, default is 0 (rows)
print("shape after:",data.shape)
# Out:
# shape before: (3008, 15)
# shape after: (1965, 15)

# %% [markdown]
# **selection of rows/columns in a dataframe**

# %%
# all rows and columns
data.iloc[:]
# Out:
#       WELL NAME  DEPTH (M)  BVW (V/V)  CARB_FLAG (UNITLESS)  \
# 0     15/9-19 A  3666.5916   0.111705                   0.0
# 1     15/9-19 A  3666.7440   0.112236                   0.0
# 2     15/9-19 A  3666.8964   0.114825                   0.0
# 3     15/9-19 A  3667.0488   0.114419                   0.0
# 4     15/9-19 A  3667.2012   0.115867                   0.0
# ...         ...        ...        ...                   ...
# 1960  15/9-19 A  3965.2956   0.138752                   0.0
# 1961  15/9-19 A  3965.4480   0.137545                   0.0
# 1962  15/9-19 A  3965.6004   0.134097                   0.0
# 1963  15/9-19 A  3965.7528   0.145216                   0.0
# 1964  15/9-19 A  3965.9052   0.143890                   0.0
#
#       COAL_FLAG (UNITLESS)  KLOGH (MD)  PHIF (V/V)  RHOFL (G/CM3)  \
# 0                      0.0      0.0003    0.199843            0.8
# 1                      0.0      0.0000    0.218743            0.8
# ...

# %%
# as a Series
data['LITHOTYPE']
# Out:
# 0               OTHER
# 1               OTHER
# 2               OTHER
# 3               OTHER
# 4       CLST.SLTY-X-X
#             ...
# 1960            OTHER
# 1961            OTHER
# 1962            OTHER
# 1963            OTHER
# 1964            OTHER
# Name: LITHOTYPE, Length: 1965, dtype: object

# %%
# select random columns
data[['WELL NAME', 'TEMP (DEGC)']]
# Out:
#       WELL NAME  TEMP (DEGC)
# 0     15/9-19 A     112.7249
# 1     15/9-19 A     112.7285
# 2     15/9-19 A     112.7321
# 3     15/9-19 A     112.7358
# 4     15/9-19 A     112.7394
# ...         ...          ...
# 1960  15/9-19 A     119.7120
# 1961  15/9-19 A     119.7156
# 1962  15/9-19 A     119.7192
# 1963  15/9-19 A     119.7227
# 1964  15/9-19 A     119.7263
#
# [1965 rows x 2 columns]

# %%
# first 3 rows (0 to 3), all columns
data[:3]
# Out:
#    WELL NAME  DEPTH (M)  BVW (V/V)  CARB_FLAG (UNITLESS)  \
# 0  15/9-19 A  3666.5916   0.111705                   0.0
# 1  15/9-19 A  3666.7440   0.112236                   0.0
# 2  15/9-19 A  3666.8964   0.114825                   0.0
#
#    COAL_FLAG (UNITLESS)  KLOGH (MD)  PHIF (V/V)  RHOFL (G/CM3)  RHOMA (G/CM3)  \
# 0                   0.0      0.0003    0.199843            0.8           2.66
# 1                   0.0      0.0000    0.218743            0.8           2.66
# 2                   0.0      0.0000    0.242380            0.8           2.66
#
#    RW (OHMM)  SAND_FLAG (UNITLESS)  SW (V/V)  TEMP (DEGC)  VSH (V/V) LITHOTYPE
# 0   0.021643                   0.0    0.5590     112.7249   0.598800     OTHER
# 1   0.021642                   0.0    0.5131     112.7285   0.599555     OTHER
# 2   0.021642                   0.0    0.4737     112.7321   0.600310     OTHER

# %%
# rows from 5 onwards (5 to last), all columns
data[5:]
# Out:
#       WELL NAME  DEPTH (M)  BVW (V/V)  CARB_FLAG (UNITLESS)  \
# 5     15/9-19 A  3667.3536   0.112858                   0.0
# 6     15/9-19 A  3667.5060   0.118716                   0.0
# 7     15/9-19 A  3667.6584   0.124121                   0.0
# 8     15/9-19 A  3667.8108   0.128317                   0.0
# 9     15/9-19 A  3667.9632   0.128881                   0.0
# ...         ...        ...        ...                   ...
# 1960  15/9-19 A  3965.2956   0.138752                   0.0
# 1961  15/9-19 A  3965.4480   0.137545                   0.0
# 1962  15/9-19 A  3965.6004   0.134097                   0.0
# 1963  15/9-19 A  3965.7528   0.145216                   0.0
# 1964  15/9-19 A  3965.9052   0.143890                   0.0
#
#       COAL_FLAG (UNITLESS)  KLOGH (MD)  PHIF (V/V)  RHOFL (G/CM3)  \
# 5                      0.0      0.0000    0.178107            0.8
# 6                      0.0      0.0000    0.197236            0.8
# ...

# %%
# selection of rows based on index which starts from 0. Here all columns but rows from 5 to 9
data.iloc[5:10,]
# Out:
#    WELL NAME  DEPTH (M)  BVW (V/V)  CARB_FLAG (UNITLESS)  \
# 5  15/9-19 A  3667.3536   0.112858                   0.0
# 6  15/9-19 A  3667.5060   0.118716                   0.0
# 7  15/9-19 A  3667.6584   0.124121                   0.0
# 8  15/9-19 A  3667.8108   0.128317                   0.0
# 9  15/9-19 A  3667.9632   0.128881                   0.0
#
#    COAL_FLAG (UNITLESS)  KLOGH (MD)  PHIF (V/V)  RHOFL (G/CM3)  RHOMA (G/CM3)  \
# 5                   0.0         0.0    0.178107            0.8           2.66
# 6                   0.0         0.0    0.197236            0.8           2.66
# 7                   0.0         0.0    0.218197            0.8           2.66
# 8                   0.0         0.0    0.243449            0.8           2.66
# 9                   0.0         0.0    0.259614            0.8           2.66
#
#    RW (OHMM)  SAND_FLAG (UNITLESS)  SW (V/V)  TEMP (DEGC)  VSH (V/V)  \
# 5   0.021640                   0.0    0.6336     112.7430   0.602575
# ...

# %%
# First four columns, and rows from 5 to 9
data.iloc[5:10, 0:4]
# Out:
#    WELL NAME  DEPTH (M)  BVW (V/V)  CARB_FLAG (UNITLESS)
# 5  15/9-19 A  3667.3536   0.112858                   0.0
# 6  15/9-19 A  3667.5060   0.118716                   0.0
# 7  15/9-19 A  3667.6584   0.124121                   0.0
# 8  15/9-19 A  3667.8108   0.128317                   0.0
# 9  15/9-19 A  3667.9632   0.128881                   0.0

# %%
# using iloc for any combination of rows and columns
selected_index =  [5, 6, 9, 15]
selected_columns = [0, 1, 5, 14]
data.iloc[selected_index, selected_columns]
# Out:
#     WELL NAME  DEPTH (M)  KLOGH (MD)      LITHOTYPE
# 5   15/9-19 A  3667.3536         0.0          OTHER
# 6   15/9-19 A  3667.5060         0.0          OTHER
# 9   15/9-19 A  3667.9632         0.0  CLST.SLTY-X-X
# 15  15/9-19 A  3668.8776         0.0          OTHER

# %%
# Merging data from another file
# Using the data from another well and merging the dataframes
data2 = pd.read_csv('data/15_9-19_BT2_CPI_LITHO.csv')

# %%
# renaming column - Well name and Common well name
data2.rename(columns={"COMMON_WELL_NAME": "WELL NAME"}, inplace=True)
# dropping NA from the dataframe 
data2.dropna(how='any', axis = 0, inplace=True) # axis = 1 denotes columns, default is 0 (rows)

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2853 entries, 0 to 2925
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   WELL NAME             2853 non-null   object
#  1   DEPTH (M)             2853 non-null   float64
#  2   BVW (V/V)             2853 non-null   float64
#  3   CARB_FLAG (UNITLESS)  2853 non-null   float64
#  4   COAL_FLAG (UNITLESS)  2853 non-null   float64
#  5   KLOGH (MD)            2853 non-null   float64
#  6   PHIF (V/V)            2853 non-null   float64
#  7   RHOFL (G/CM3)         2853 non-null   float64
#  8   RHOMA (G/CM3)         2853 non-null   float64
#  9   RW (OHMM)             2853 non-null   float64
#  10  SAND_FLAG (UNITLESS)  2853 non-null   float64
#  11  SW (V/V)              2853 non-null   float64
#  12  TEMP (DEGC)           2853 non-null   float64
#  13  VSH (V/V)             2853 non-null   float64
# ...

# %% [markdown]
# To merge the datasets from different sources, it is possible to combine them by multiple ways. A brief description is provided below.
#
# syntax: pd.merge(left, right, how, on)
#
# Here, left and right indicate the first and second dataframe which are required to be merged
#
# 1. how = 'outer', This allows to take the union of datasets and append them together.
# 2. how = 'inner', This allows to take the intersection of datasets and keep only the common values
# 3. how = 'left', All indexes of left dataframe are included. If there are indexes which are not present in the 'left' dataframe, they will not be included in the merged dataset
# 4. how = 'right', All indexes of right dataframe are included. If there are indexes which are not present in the 'right' dataframe, they will not be included in the merged dataset
#
# <img src="imgs/joinven.png" />
#
# The keyword 'on' decides if the dataframes are merged on a particular ID which is a unique identifier. Eg. API Number in oil and gas wells.

# %%
data_combined = pd.merge(data, data2, how='outer', on = None)
data_combined.shape
# Out:
# (4818, 15)

# %% [markdown]
# **Matplotlib - Python Data Visualization Library**

# %%
# Default Style Changes
# https://matplotlib.org/3.1.1/users/dflt_style_changes.html
import matplotlib.style
import matplotlib as mpl
import matplotlib.pyplot as plt
plt.rcParams['axes.labelsize'] = 16
plt.rcParams['axes.labelweight'] = 'bold'
plt.rcParams['image.cmap'] = 'gray'
mpl.style.use('classic')
mpl.rcParams['grid.color'] = 'k'
mpl.rcParams['grid.linestyle'] = ':'
mpl.rcParams['grid.linewidth'] = 0.5
mpl.rcParams['figure.figsize'] = [12,12]
mpl.rcParams['figure.dpi'] = 120
mpl.rcParams['savefig.dpi'] = 300
mpl.rcParams['font.size'] = 12
mpl.rcParams['legend.fontsize'] = 'large'
mpl.rcParams['figure.titlesize'] = 'medium'
mpl.rcParams['patch.force_edgecolor'] = True
mpl.rcParams['patch.facecolor'] = 'b'

# %%
# 
# The determination of the shale volume is necessary for formations properties, 
# because it is important for computing fluid content, formation porosity and formation permeability.
# for inline plotting
# %matplotlib inline
# for interactive plot
#%matplotlib

# creating a figure with size (8,8) in inches
plt.figure(figsize=[8,8])

# x axis: VSH
x = data['VSH (V/V)']
# y axis: depth
y = data['DEPTH (M)']
# setting x label
plt.xlabel('VSH', fontsize=15)
# setting y label
plt.ylabel('Depth (m)', fontsize=15)
# setting title
plt.title('Line Chart Example', fontsize=20)
# Line Plot
plt.plot(x, y)
plt.show()

# %%
# Scatter Plot Example on Log-log scale

# KLOGH (mD): log-evaluated permeability
# SW (V/V) - Water Saturation


# creating a figure with size (8,8) in inches
plt.figure(figsize=[8,8])

# x axis: KLOGH
x = data['KLOGH (MD)']
# y axis: depth
y = data['SW (V/V)']

# s denotes the size of the bubbles in scatter plot
plt.scatter(x,y, s=8, label='SW') 

# setting x label
plt.xlabel('KLOGH (MD)', fontsize=15)
# setting y label
plt.ylabel('SW (V/V)', fontsize=15)
# setting title
plt.title('Scatter Plot Example', fontsize=20)
# adding ticks on both axes
plt.tick_params(axis='both', which='major', labelsize=14)
# adding legend at best figure location
plt.legend(loc='best')
# making x axis log scale
plt.xscale('log')
# making y axis log scale
plt.yscale('log')
# setting the limit for x axis
plt.xlim(10,10000)
# setting the limit for y axis
plt.ylim(0.01, 10)
# Out:
# (0.01, 10)

# %%
plt.figure(figsize=[8,8])
plt.hist(data_combined['LITHOTYPE'])

plt.xlabel('Facies', fontsize=15)
plt.ylabel('Frequency', fontsize=15)
plt.title('Histogram Example', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=14)
plt.xticks(rotation=90)
plt.show()

# %%
# save the combined dataframe to .csv file for future projects
data_combined.to_csv('data/Merged_Data.csv', index=False)
